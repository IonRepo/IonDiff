# %%
import numpy as np
import logging
import json

from IonDiff import analyze_descriptors  as AD_library

from datetime import datetime

# %% [markdown]
# Analysis of atomistic descriptors extracted from the diffusive paths (under active development).
#
# At the input folder, a XDATCAR file with all the configurations of the system through simulation is required.
# Optionally, a POSCAR can be supplied with the initial configuration.
# As well, an INCAR specifying POTIM (simulation time step) and NBLOCK (number of simulation steps between
# consecutive configurations in the XDATCAR) is necessary.

# %% [markdown]
# /home/claudio/Desktop/HfO2/tetra/3000K
# /home/claudio/Desktop/HfO2/tetra/2500K

# %%
class args:
    def __init__(self):
        args.MD_path        = '/home/claudio/Desktop/HfO2/tetra/3000K'  # Path to the input molecular dynamics simulation files
        args.reference_path = '/home/claudio/Desktop/HfO2/tetra/3000K'  # Path to a folder with a stoichiometric POSCAR structure file for the simulation of the given material

# Initialize class
args = args()

# %%
# Configuring loggin information
logging.basicConfig(
    filename=f'logs/analyze_descriptors_{datetime.now().strftime("%Y-%m-%d_%H:%M:%S")}.log',
    format='%(asctime)s - [%(levelname)s] - %(message)s',
    level=logging.INFO,
)

# Saving logging information
logging.info(f'Task: Analysing atomistic descriptors from MD simulations database at {args.MD_path}.')

# Calling the library and loading the class
inp = AD_library.descriptors(args)

# Computing descriptors
time_interval      = inp.time_until_diffusion()
temporal_duration  = inp.duration_of_diffusion()
spatial_length     = inp.length_of_diffusion(outer='nan')
n_diffusive_events = inp.n_diffusive_events()
residence_time, metastable, non_metastable = inp.residence_time(args)

# Save descriptors as dictionary
descriptors = {
    'MD_path':      args.MD_path,
    'delta_t_min':  np.min(time_interval),
    'delta_t_max':  np.max(time_interval),
    'delta_t_mean': np.mean(time_interval),
    'delta_r_min':  np.min(temporal_duration),
    'delta_r_max':  np.max(temporal_duration),
    'delta_r_mean': np.mean(temporal_duration),
    'gamma':        residence_time
}

# Logging update
logging.info(f'Descriptors successfully extracted.')

# Write the dictionary to the file in JSON format
with open(f'{args.MD_path}/atomistic_descriptors.json', 'w') as json_file:
    json.dump(descriptors, json_file)

# Logging update
logging.info(f'Descriptors successfully saved.')
# Out:
# [[[0.32222333 0.07722333 0.25055667]
#   [0.65555667 0.07722333 0.25055667]
#   [0.98889    0.07722333 0.25055667]
#   ...
#   [0.058606   0.99389    0.83389   ]
#   [0.39193934 0.99389    0.83389   ]
#   [0.72527267 0.99389    0.83389   ]]
#
#  [[0.31020643 0.06288521 0.26399411]
#   [0.64606147 0.0722918  0.26230741]
#   [0.98391909 0.08107224 0.24732646]
#   ...
#   [0.07400248 0.99092205 0.82632922]
#   [0.40606396 0.99040687 0.82591967]
#   [0.7194579  0.9883165  0.82726338]]
#
#  [[0.29642577 0.05006074 0.27286106]
#   [0.63438245 0.06517504 0.27336662]
#   [0.98742234 0.0858065  0.23759289]
#   ...
#   [0.04720695 0.99841416 0.80988118]
#   [0.38978924 0.03534749 0.82851852]
# [[[nan nan nan]
#   [nan nan nan]
#   [nan nan nan]
#   ...
#   [nan nan nan]
#   [nan nan nan]
#   [nan nan nan]]
#
#  [[nan nan nan]
#   [nan nan nan]
#   [nan nan nan]
#   ...
#   [nan nan nan]
#   [nan nan nan]
#   [nan nan nan]]
#
#  [[nan nan nan]
#   [nan nan nan]
#   [nan nan nan]
#   ...
#   [nan nan nan]
#   [nan nan nan]
#   [nan nan nan]]
#
#  ...
#
#  [[nan nan nan]
#   [nan nan nan]
#   [nan nan nan]
#   ...
#   [nan nan nan]
#   [nan nan nan]
#   [nan nan nan]]
#
#  [[nan nan nan]
#   [nan nan nan]
#   [nan nan nan]
#   ...
#   [nan nan nan]
#   [nan nan nan]
#   [nan nan nan]]
#
#  [[nan nan nan]
#   [nan nan nan]
#   [nan nan nan]
#   ...
#   [nan nan nan]
#   [nan nan nan]
#   [nan nan nan]]]
# [[nan nan nan]
#  [nan nan nan]
#  [nan nan nan]
#  ...
#  [nan nan nan]
#  [nan nan nan]
#  [nan nan nan]]
# /home/claudio/cibran/Work/UPC/IonDiff/IonDiff/common_library.py:90: SyntaxWarning: invalid escape sequence '\d'
#   split_compound = re.split('(\d+)', element)  # Splitting by numbers
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 19
#      17 spatial_length     = inp.length_of_diffusion(outer='nan')
#      18 n_diffusive_events = inp.n_diffusive_events()
# ---> 19 residence_time, metastable, non_metastable = inp.residence_time(args)
#      21 # Save descriptors as dictionary
#      22 descriptors = {
#      23     'MD_path':      args.MD_path,
#      24     'delta_t_min':  np.min(time_interval),
#    (...)     30     'gamma':        residence_time
#      31 }
#
# File ~/cibran/Work/UPC/IonDiff/IonDiff/analyze_descriptors.py:259, in descriptors.residence_time(self, args, threshold)
#     257 coordinates_i = cartesian_coordinates[:, particle]
#     258 print(coordinates_i)
# --> 259 n_clusters = CL.calculate_silhouette(coordinates_i,
#     260                                      'K-means',
#     261                                      10,
#     262                                      0.7)
#     264 if n_clusters > 1:
#     265     centers, classification, _, _ = CL.calculate_clusters(coordinates_i,
#     266                                                           n_clusters,
#     267                                                           'K-means',
#     268                                                           0.4)
#
# File ~/cibran/Work/UPC/IonDiff/IonDiff/common_library.py:484, in calculate_silhouette(coordinates, method, n_attempts, silhouette_thd)
#     481 else:                      sys.exit('Error: clustering method not recognized')
#     483 # Getting the labels
# --> 484 labels = clustering.fit_predict(coordinates)
#     486 # Calculate distortion for a range of number of cluster
#     487 silhouette_averages.append(silhouette_score(coordinates, labels))
#
# File ~/cibran/Work/UPC/IonDiff/.venv/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:1064, in _BaseKMeans.fit_predict(self, X, y, sample_weight)
#    1041 def fit_predict(self, X, y=None, sample_weight=None):
#    1042     """Compute cluster centers and predict cluster index for each sample.
#    1043
#    1044     Convenience method; equivalent to calling fit(X) followed by
#    (...)   1062         Index of the cluster each sample belongs to.
#    1063     """
# -> 1064     return self.fit(X, sample_weight=sample_weight).labels_
#
# File ~/cibran/Work/UPC/IonDiff/.venv/lib/python3.12/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/cibran/Work/UPC/IonDiff/.venv/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:1454, in KMeans.fit(self, X, y, sample_weight)
#    1426 @_fit_context(prefer_skip_nested_validation=True)
#    1427 def fit(self, X, y=None, sample_weight=None):
#    1428     """Compute k-means clustering.
#    1429
#    1430     Parameters
#    (...)   1452         Fitted estimator.
#    1453     """
# -> 1454     X = validate_data(
#    1455         self,
#    1456         X,
#    1457         accept_sparse="csr",
#    1458         dtype=[np.float64, np.float32],
#    1459         order="C",
#    1460         copy=self.copy_x,
#    1461         accept_large_sparse=False,
#    1462     )
#    1464     self._check_params_vs_input(X)
#    1466     random_state = check_random_state(self.random_state)
#
# File ~/cibran/Work/UPC/IonDiff/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2954, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2952         out = X, y
#    2953 elif not no_val_X and no_val_y:
# -> 2954     out = check_array(X, input_name="X", **check_params)
#    2955 elif no_val_X and not no_val_y:
#    2956     out = _check_y(y, **check_params)
#
# File ~/cibran/Work/UPC/IonDiff/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:1105, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1099     raise ValueError(
#    1100         f"Found array with dim {array.ndim},"
#    1101         f" while dim <= 2 is required{context}."
#    1102     )
#    1104 if ensure_all_finite:
# -> 1105     _assert_all_finite(
#    1106         array,
#    1107         input_name=input_name,
#    1108         estimator_name=estimator_name,
#    1109         allow_nan=ensure_all_finite == "allow-nan",
#    1110     )
#    1112 if copy:
#    1113     if _is_numpy_namespace(xp):
#    1114         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~/cibran/Work/UPC/IonDiff/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File ~/cibran/Work/UPC/IonDiff/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# KMeans does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
